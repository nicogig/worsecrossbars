# %%
import os
import pickle
from pathlib import Path
import matplotlib.font_manager as fm
import numpy as np

from plotting import training_validation_plotter

# %%
# Importing LaTeX font for plots
os.system('wget -O cmunrm.ttf https://github.com/nicogig/ComputerModern/raw/main/cmunrm.ttf > /dev/null 2>&1')

#!wget -O cmunrm.ttf https://github.com/nicogig/ComputerModern/raw/main/cmunrm.ttf

fpath = Path('cmunrm.ttf')
font = fm.FontProperties(fname='cmunrm.ttf', size=18)

# %%
# Opening training/validation arrays from files

accuracy_values = []
validation_accuracy_values = []
loss_values = []
validation_loss_values = []

for number_hidden_layers in range(1, 5):

    accuracy_values.append(pickle.load(open("saved_data/training_validation_{}HL.p".format(number_hidden_layers), "rb"))[0])
    validation_accuracy_values.append(pickle.load(open("saved_data/training_validation_{}HL.p".format(number_hidden_layers), "rb"))[1])
    loss_values.append(pickle.load(open("saved_data/training_validation_{}HL.p".format(number_hidden_layers), "rb"))[2])
    validation_loss_values.append(pickle.load(open("saved_data/training_validation_{}HL.p".format(number_hidden_layers), "rb"))[3])

epochs = np.arange(1, len(accuracy_values[0])+1)

# %%
# Plotting 1-layer accuracy curves

training_validation_plotter(epochs, accuracy_values[0], validation_accuracy_values[0], "Accuracy", font)
training_validation_plotter(epochs, loss_values[0], validation_loss_values[0], "Loss", font)

# %%
# Plotting 2-layer accuracy curves

training_validation_plotter(epochs, accuracy_values[1], validation_accuracy_values[1], "Accuracy", font)
training_validation_plotter(epochs, loss_values[1], validation_loss_values[1], "Loss", font)

# %%
# Plotting 3-layer accuracy curves

training_validation_plotter(epochs, accuracy_values[2], validation_accuracy_values[2], "Accuracy", font)
training_validation_plotter(epochs, loss_values[2], validation_loss_values[2], "Loss", font)

# %%
# Plotting 4-layer accuracy curves

training_validation_plotter(epochs, accuracy_values[3], validation_accuracy_values[3], "Accuracy", font)
training_validation_plotter(epochs, loss_values[3], validation_loss_values[3], "Loss", font)

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=81ea8185-215e-49ca-bfae-d3424caf9524' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
